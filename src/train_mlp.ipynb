# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 1
batch_size = 32
epochs= 15
dropout_rate = 0.3
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature length:  (37,)
# Model: "model_119"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_120 (InputLayer)      [(None, 37)]              0
#
#  dense_357 (Dense)           (None, 128)               4864
#
#  dense_358 (Dense)           (None, 64)                8256
#
#  dropout_89 (Dropout)        (None, 64)                0
#
#  dense_359 (Dense)           (None, 7)                 455
#
# ...
# Total params: 13,575
# Trainable params: 13,575
# Non-trainable params: 0
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 2
batch_size = 32
epochs= 15
dropout_rate = 0.3
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature length:  (70,)
# Model: "model_129"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_130 (InputLayer)      [(None, 70)]              0
#
#  dense_387 (Dense)           (None, 128)               9088
#
#  dense_388 (Dense)           (None, 64)                8256
#
#  dropout_99 (Dropout)        (None, 64)                0
#
#  dense_389 (Dense)           (None, 7)                 455
#
# ...
# Total params: 17,799
# Trainable params: 17,799
# Non-trainable params: 0
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 3
batch_size = 32
epochs= 15
dropout_rate = 0.3
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature length:  (103,)
# Model: "model_139"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_140 (InputLayer)      [(None, 103)]             0
#
#  dense_417 (Dense)           (None, 128)               13312
#
#  dense_418 (Dense)           (None, 64)                8256
#
#  dropout_109 (Dropout)       (None, 64)                0
#
#  dense_419 (Dense)           (None, 7)                 455
#
# ...
# Total params: 22,023
# Trainable params: 22,023
# Non-trainable params: 0
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 4
batch_size = 32
epochs= 15
dropout_rate = 0.3
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature length:  (136,)
# Model: "model_99"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_100 (InputLayer)      [(None, 136)]             0
#
#  dense_297 (Dense)           (None, 128)               17536
#
#  dense_298 (Dense)           (None, 64)                8256
#
#  dropout_69 (Dropout)        (None, 64)                0
#
#  dense_299 (Dense)           (None, 7)                 455
#
# ...
# Total params: 26,247
# Trainable params: 26,247
# Non-trainable params: 0
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 5
batch_size = 32
epochs= 15
dropout_rate = 0.3
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature length:  (169,)
# Restoring model weights from the end of the best epoch: 5.
# Epoch 15: early stopping
# Model: "model_149"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_150 (InputLayer)      [(None, 169)]             0
#
#  dense_447 (Dense)           (None, 128)               21760
#
#  dense_448 (Dense)           (None, 64)                8256
#
#  dropout_119 (Dropout)       (None, 64)                0
#
#  dense_449 (Dense)           (None, 7)                 455
#
# ...
# Total params: 30,471
# Trainable params: 30,471
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'NEU-CLS'
n_folds = 10
wavelet = 'haar'
level = 1
batch_size = 32
epochs= 10
dropout_rate = 0.5
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature length:  (37,)
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_10 (InputLayer)       [(None, 37)]              0
#
#  dense_27 (Dense)            (None, 128)               4864
#
#  dense_28 (Dense)            (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_29 (Dense)            (None, 6)                 390
#
# ...
# Total params: 13,510
# Trainable params: 13,510
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------------------------------------------------------------
# Score per fold
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'NEU-CLS'
n_folds = 10
wavelet = 'haar'
level = 2
batch_size = 32
epochs= 10
dropout_rate = 0.5
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature length:  (70,)
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_20 (InputLayer)       [(None, 70)]              0
#
#  dense_57 (Dense)            (None, 128)               9088
#
#  dense_58 (Dense)            (None, 64)                8256
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_59 (Dense)            (None, 6)                 390
#
# ...
# Total params: 17,734
# Trainable params: 17,734
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------------------------------------------------------------
# Score per fold
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'NEU-CLS'
n_folds = 10
wavelet = 'haar'
level = 3
batch_size = 32
epochs= 10
dropout_rate = 0.5
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature length:  (103,)
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_30 (InputLayer)       [(None, 103)]             0
#
#  dense_87 (Dense)            (None, 128)               13312
#
#  dense_88 (Dense)            (None, 64)                8256
#
#  dropout_29 (Dropout)        (None, 64)                0
#
#  dense_89 (Dense)            (None, 6)                 390
#
# ...
# Total params: 21,958
# Trainable params: 21,958
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------------------------------------------------------------
# Score per fold
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'NEU-CLS'
n_folds = 10
wavelet = 'haar'
level = 4
batch_size = 32
epochs= 10
dropout_rate = 0.5
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature length:  (136,)
# Training for fold 1 ...
# Training for fold 2 ...
# Training for fold 3 ...
# Training for fold 4 ...
# Training for fold 5 ...
# Training for fold 6 ...
# Training for fold 7 ...
# Training for fold 8 ...
# Training for fold 9 ...
# Training for fold 10 ...
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_30 (InputLayer)       [(None, 136)]             0
#
#  dense_87 (Dense)            (None, 128)               17536
#
#  dense_88 (Dense)            (None, 64)                8256
#
#  dropout_29 (Dropout)        (None, 64)                0
#
#  dense_89 (Dense)            (None, 6)                 390
#
# ...

# %%
from mlp_wt_model import print_results, plot_results, train

dataset_name = 'NEU-CLS'
n_folds = 10
wavelet = 'haar'
level = 5
batch_size = 32
epochs= 10
dropout_rate = 0.5
results = train(dataset_name = dataset_name, 
                n_folds = n_folds, 
                wavelet = wavelet, 
                level = level,
                batch_size = batch_size,
                epochs = epochs,
                dropout_rate = dropout_rate)

(acc_per_fold, loss_per_fold, fold_histories, macro_recall_per_fold, 
     macro_precision_per_fold, macro_f1_per_fold, misclassified_info) = results

print_results(dataset_name, level, acc_per_fold, loss_per_fold, macro_recall_per_fold, 
                macro_precision_per_fold, macro_f1_per_fold)

plot_results(fold_histories)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature length:  (169,)
# Model: "model_159"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_160 (InputLayer)      [(None, 169)]             0
#
#  dense_477 (Dense)           (None, 128)               21760
#
#  dense_478 (Dense)           (None, 64)                8256
#
#  dropout_129 (Dropout)       (None, 64)                0
#
#  dense_479 (Dense)           (None, 6)                 390
#
# ...
# Total params: 30,406
# Trainable params: 30,406
# Non-trainable params: 0
# _________________________________________________________________
# --------------------------------------------------------------------------------------------------
# Score per fold
# ...
