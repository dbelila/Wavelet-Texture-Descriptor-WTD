# %%
# RFE over features in all levels
from features_analysis import *    

dataset_name = 'NEU-CLS-10'
df, feature_names, labels = load_data(dataset_name)
iteration_number = 1
fold = 10


print("------------------------------------------")
print(" Performing RFE on features ")
# Perform RFE to select the best features combination on selected levels
best_accuracy, feature_types, selected_features = rfe(df, labels, initial_feature_types, iteration_number, fold, grid_search=True)

print("> Dataset_name: ", dataset_name)
print(f" - Best accuracy: {best_accuracy*100:.2f}")
print(f" - Selected feature : {feature_types}")
# Out:
# ------------------------------------------
#  Performing RFE on features
#
# -----------------------------------------------
# - Iteration: 1
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 100.00 (0.0000)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing kurtosis: 100.00 (0.0000)
# Accuracy after removing contrast: 100.00 (0.0000)
# Accuracy after removing dissimilarity: 100.00 (0.0000)
# Accuracy after removing homogeneity: 100.00 (0.0000)
# Accuracy after removing energy: 100.00 (0.0000)
# Accuracy after removing correlation: 100.00 (0.0000)
# Accuracy after removing lbp: 100.00 (0.0000)
# Accuracy after removing spectral_energy: 100.00 (0.0000)
# Accuracy after removing spectral_entropy: 100.00 (0.0000)
# - Removing feature: spectral_entropy improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 2
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 100.00 (0.0000)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing kurtosis: 100.00 (0.0000)
# Accuracy after removing contrast: 100.00 (0.0000)
# Accuracy after removing dissimilarity: 100.00 (0.0000)
# Accuracy after removing homogeneity: 100.00 (0.0000)
# Accuracy after removing energy: 100.00 (0.0000)
# Accuracy after removing correlation: 100.00 (0.0000)
# Accuracy after removing lbp: 100.00 (0.0000)
# Accuracy after removing spectral_energy: 100.00 (0.0000)
# - Removing feature: spectral_energy improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 3
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 100.00 (0.0000)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing kurtosis: 100.00 (0.0000)
# Accuracy after removing contrast: 100.00 (0.0000)
# Accuracy after removing dissimilarity: 100.00 (0.0000)
# Accuracy after removing homogeneity: 100.00 (0.0000)
# Accuracy after removing energy: 100.00 (0.0000)
# Accuracy after removing correlation: 100.00 (0.0000)
# Accuracy after removing lbp: 100.00 (0.0000)
# - Removing feature: lbp improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 4
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 100.00 (0.0000)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing kurtosis: 100.00 (0.0000)
# Accuracy after removing contrast: 100.00 (0.0000)
# Accuracy after removing dissimilarity: 100.00 (0.0000)
# Accuracy after removing homogeneity: 100.00 (0.0000)
# Accuracy after removing energy: 100.00 (0.0000)
# Accuracy after removing correlation: 100.00 (0.0000)
# - Removing feature: correlation improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 5
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 98.33 (-1.6667)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing kurtosis: 100.00 (0.0000)
# Accuracy after removing contrast: 98.33 (-1.6667)
# Accuracy after removing dissimilarity: 100.00 (0.0000)
# Accuracy after removing homogeneity: 100.00 (0.0000)
# Accuracy after removing energy: 98.33 (-1.6667)
# - Removing feature: homogeneity improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 6
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 96.67 (-3.3333)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing kurtosis: 100.00 (0.0000)
# Accuracy after removing contrast: 98.33 (-1.6667)
# Accuracy after removing dissimilarity: 100.00 (0.0000)
# Accuracy after removing energy: 98.33 (-1.6667)
# - Removing feature: dissimilarity improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 7
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 95.00 (-5.0000)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing kurtosis: 100.00 (0.0000)
# Accuracy after removing contrast: 96.67 (-3.3333)
# Accuracy after removing energy: 98.33 (-1.6667)
# - Removing feature: kurtosis improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 8
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 95.00 (-5.0000)
# Accuracy after removing skewness: 100.00 (0.0000)
# Accuracy after removing contrast: 96.67 (-3.3333)
# Accuracy after removing energy: 98.33 (-1.6667)
# - Removing feature: skewness improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 9
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 96.67 (-3.3333)
# Accuracy after removing contrast: 96.67 (-3.3333)
# Accuracy after removing energy: 100.00 (0.0000)
# - Removing feature: energy improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 10
# Accuracy with all features: 100.00
# Accuracy after removing mean: 100.00 (0.0000)
# Accuracy after removing variance: 95.00 (-5.0000)
# Accuracy after removing contrast: 95.00 (-5.0000)
# - Removing feature: mean improved accuracy to: 100.00 (0.00)
#
# -----------------------------------------------
# - Iteration: 11
# Accuracy with all features: 100.00
# Accuracy after removing variance: 93.33 (-6.6667)
# Accuracy after removing contrast: 95.00 (-5.0000)
# > Dataset_name:  NEU-CLS-10
#  - Best accuracy: 100.00
#  - Selected feature : ['variance', 'contrast']

# %%
from models import *
from features_analysis import load_data, select_features

dataset_name = 'NEU-CLS-10'
fold = 10

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_neu)
results = svm_model(selected_df.values, labels, fold)


best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results

print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 100.00 % - Loss: 0.3996 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 100.00 % - Loss: 0.4774 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.2900 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 100.00 % - Loss: 0.3883 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.4028 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.4339 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 100.00 % - Loss: 0.3457 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 100.00 % - Loss: 0.5510 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 100.00 % - Loss: 0.3393 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 100.00 % - Loss: 0.3618 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS-10
# - Classifier parameters:  {'C': 1, 'gamma': 0.01}
# > Accuracy: 100.00 (+- 0.00)
# > Loss: 0.3990
# > Precision: 100.00 (+- 0.00)
# > Recall: 100.00 (+- 0.00)
# > F1 Score: 100.00 (+- 0.00)
# ----------------------------------------------------------------

# %%
# RFE over features in all levels
from features_analysis import *    

dataset_name = 'X-SDD-10'
df, feature_names, labels = load_data(dataset_name)
iteration_number = 1
fold = 10


print("------------------------------------------")
print(" Performing RFE on features ")
# Perform RFE to select the best features combination on selected levels
best_accuracy, feature_types, selected_features = rfe(df, labels, initial_feature_types, iteration_number, fold, grid_search=True)

print("> Dataset_name: ", dataset_name)
print(f" - Best accuracy: {best_accuracy*100:.2f}")
print(f" - Selected feature : {feature_types}")
# Out:
# ------------------------------------------
#  Performing RFE on features
#
# -----------------------------------------------
# - Iteration: 1
# Accuracy with all features: 98.57
# Accuracy after removing mean: 98.57 (0.0000)
# Accuracy after removing variance: 98.57 (0.0000)
# Accuracy after removing skewness: 98.57 (0.0000)
# Accuracy after removing kurtosis: 98.57 (0.0000)
# Accuracy after removing contrast: 98.57 (0.0000)
# Accuracy after removing dissimilarity: 98.57 (0.0000)
# Accuracy after removing homogeneity: 98.57 (0.0000)
# Accuracy after removing energy: 98.57 (0.0000)
# Accuracy after removing correlation: 98.57 (0.0000)
# Accuracy after removing lbp: 97.14 (-1.4286)
# Accuracy after removing spectral_energy: 98.57 (0.0000)
# Accuracy after removing spectral_entropy: 98.57 (0.0000)
# - Removing feature: spectral_entropy improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 2
# Accuracy with all features: 98.57
# Accuracy after removing mean: 98.57 (0.0000)
# Accuracy after removing variance: 98.57 (0.0000)
# Accuracy after removing skewness: 98.57 (0.0000)
# Accuracy after removing kurtosis: 98.57 (0.0000)
# Accuracy after removing contrast: 98.57 (0.0000)
# Accuracy after removing dissimilarity: 98.57 (0.0000)
# Accuracy after removing homogeneity: 98.57 (0.0000)
# Accuracy after removing energy: 98.57 (0.0000)
# Accuracy after removing correlation: 98.57 (0.0000)
# Accuracy after removing lbp: 97.14 (-1.4286)
# Accuracy after removing spectral_energy: 98.57 (0.0000)
# - Removing feature: spectral_energy improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 3
# Accuracy with all features: 98.57
# Accuracy after removing mean: 98.57 (0.0000)
# Accuracy after removing variance: 98.57 (0.0000)
# Accuracy after removing skewness: 98.57 (0.0000)
# Accuracy after removing kurtosis: 98.57 (0.0000)
# Accuracy after removing contrast: 98.57 (0.0000)
# Accuracy after removing dissimilarity: 98.57 (0.0000)
# Accuracy after removing homogeneity: 98.57 (0.0000)
# Accuracy after removing energy: 98.57 (0.0000)
# Accuracy after removing correlation: 98.57 (0.0000)
# Accuracy after removing lbp: 97.14 (-1.4286)
# - Removing feature: correlation improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 4
# Accuracy with all features: 98.57
# Accuracy after removing mean: 98.57 (0.0000)
# Accuracy after removing variance: 98.57 (0.0000)
# Accuracy after removing skewness: 98.57 (0.0000)
# Accuracy after removing kurtosis: 98.57 (0.0000)
# Accuracy after removing contrast: 98.57 (0.0000)
# Accuracy after removing dissimilarity: 98.57 (0.0000)
# Accuracy after removing homogeneity: 98.57 (0.0000)
# Accuracy after removing energy: 98.57 (0.0000)
# Accuracy after removing lbp: 97.14 (-1.4286)
# - Removing feature: energy improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 5
# Accuracy with all features: 98.57
# Accuracy after removing mean: 98.57 (0.0000)
# Accuracy after removing variance: 98.57 (0.0000)
# Accuracy after removing skewness: 98.57 (0.0000)
# Accuracy after removing kurtosis: 98.57 (0.0000)
# Accuracy after removing contrast: 98.57 (0.0000)
# Accuracy after removing dissimilarity: 98.57 (0.0000)
# Accuracy after removing homogeneity: 98.57 (0.0000)
# Accuracy after removing lbp: 97.14 (-1.4286)
# - Removing feature: homogeneity improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 6
# Accuracy with all features: 98.57
# Accuracy after removing mean: 97.14 (-1.4286)
# Accuracy after removing variance: 97.14 (-1.4286)
# Accuracy after removing skewness: 98.57 (0.0000)
# Accuracy after removing kurtosis: 98.57 (0.0000)
# Accuracy after removing contrast: 97.14 (-1.4286)
# Accuracy after removing dissimilarity: 97.14 (-1.4286)
# Accuracy after removing lbp: 95.71 (-2.8571)
# - Removing feature: kurtosis improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 7
# Accuracy with all features: 98.57
# Accuracy after removing mean: 98.57 (0.0000)
# Accuracy after removing variance: 97.14 (-1.4286)
# Accuracy after removing skewness: 97.14 (-1.4286)
# Accuracy after removing contrast: 98.57 (0.0000)
# Accuracy after removing dissimilarity: 98.57 (0.0000)
# Accuracy after removing lbp: 97.14 (-1.4286)
# - Removing feature: dissimilarity improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 8
# Accuracy with all features: 98.57
# Accuracy after removing mean: 97.14 (-1.4286)
# Accuracy after removing variance: 98.57 (0.0000)
# Accuracy after removing skewness: 95.71 (-2.8571)
# Accuracy after removing contrast: 97.14 (-1.4286)
# Accuracy after removing lbp: 90.00 (-8.5714)
# - Removing feature: variance improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 9
# Accuracy with all features: 98.57
# Accuracy after removing mean: 98.57 (0.0000)
# Accuracy after removing skewness: 97.14 (-1.4286)
# Accuracy after removing contrast: 98.57 (0.0000)
# Accuracy after removing lbp: 90.00 (-8.5714)
# - Removing feature: contrast improved accuracy to: 98.57 (0.00)
#
# -----------------------------------------------
# - Iteration: 10
# Accuracy with all features: 98.57
# Accuracy after removing mean: 97.14 (-1.4286)
# Accuracy after removing skewness: 94.29 (-4.2857)
# Accuracy after removing lbp: 65.71 (-32.8571)
# > Dataset_name:  X-SDD-10
#  - Best accuracy: 98.57
#  - Selected feature : ['mean', 'skewness', 'lbp']

# %%
from models import *
from features_analysis import load_data, select_features

dataset_name = 'X-SDD-10'
fold = 10

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_xsdd)
results = svm_model(selected_df.values, labels, fold)


best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results

print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 100.00 % - Loss: 0.3434 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 100.00 % - Loss: 0.4532 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.3924 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 100.00 % - Loss: 0.4817 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.4343 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.5165 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 100.00 % - Loss: 0.4405 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 100.00 % - Loss: 0.5000 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 85.71 % - Loss: 0.9501 - Precision: 78.57 % - Recall: 85.71 % - F1 Score: 80.95 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 100.00 % - Loss: 0.4369 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD-10
# - Classifier parameters:  {'C': 1, 'gamma': 'scale'}
# > Accuracy: 98.57 (+- 4.29)
# > Loss: 0.4949
# > Precision: 97.86 (+- 6.43)
# > Recall: 98.57 (+- 4.29)
# > F1 Score: 98.10 (+- 5.71)
# ----------------------------------------------------------------
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
