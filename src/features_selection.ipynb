# %%
# RFE over features in all levels
from features_analysis import *    

dataset_name = 'X-SDD'
df, feature_names, labels = load_data(dataset_name)
iteration_number = 1
fold = 10


print("------------------------------------------")
print(" Performing RFE on features ")
# Perform RFE to select the best features combination on selected levels
best_accuracy, feature_types, selected_features = rfe(df, labels, initial_feature_types, iteration_number, fold)

print("> Dataset_name: ", dataset_name)
print(f"Best accuracy: {best_accuracy*100:.2f}")
print(f"Selected feature : {feature_types}")

print("------------------------------------------")
print(" Performing RFE on level after selected features ")
level_feature_types = ['_1_', '_2_', '_3_', '_4_', '_5_']

# Perform RFE to select the best level combination
best_accuracy, feature_types, selected_features = rfe(selected_features, labels, level_feature_types, iteration_number, fold)

print("------------------------------------------")
print(" Performing RFE on levels")
print("> Dataset_name: ", dataset_name)
print(f"Best accuracy: {best_accuracy*100:.2f}")
print(f"Selected level : {feature_types}")

levels = ['_1_', '_2_', '_3_', '_4_', '_5_']
# Train the model with selected features in one level
print("---------------------------------------")
print("Individiual level accuracy on selected features:")
print("> Dataset_name: ", dataset_name)
# Train the model for each level with all features combined
for level in levels:
    df_isolated = isolate_level_features(selected_features, level=level)
    acc = train(df_isolated, labels, fold)
    print(f" - Level: {level} Individual accuracy: {acc*100:.2f}")

print("---------------------------------------")
# Out:
# ------------------------------------------
#  Performing RFE on features
#
# -----------------------------------------------
# - Iteration: 1
# Accuracy with all features: 97.50
# Accuracy after removing mean: 97.65 (0.1471)
# Accuracy after removing variance: 97.50 (0.0000)
# Accuracy after removing skewness: 97.57 (0.0735)
# Accuracy after removing kurtosis: 97.65 (0.1471)
# Accuracy after removing contrast: 97.43 (-0.0735)
# Accuracy after removing dissimilarity: 97.65 (0.1471)
# Accuracy after removing homogeneity: 97.50 (0.0000)
# Accuracy after removing energy: 97.57 (0.0735)
# Accuracy after removing correlation: 97.28 (-0.2206)
# Accuracy after removing lbp: 97.06 (-0.4412)
# Accuracy after removing spectral_energy: 97.50 (0.0000)
# Accuracy after removing spectral_entropy: 96.99 (-0.5147)
# - Removing feature: dissimilarity improved accuracy to: 97.65 (0.15)
#
# -----------------------------------------------
# - Iteration: 2
# Accuracy with all features: 97.65
# Accuracy after removing mean: 97.65 (0.0000)
# Accuracy after removing variance: 97.50 (-0.1471)
# Accuracy after removing skewness: 97.35 (-0.2941)
# Accuracy after removing kurtosis: 97.65 (0.0000)
# Accuracy after removing contrast: 96.69 (-0.9559)
# Accuracy after removing homogeneity: 97.57 (-0.0735)
# Accuracy after removing energy: 97.50 (-0.1471)
# Accuracy after removing correlation: 97.21 (-0.4412)
# Accuracy after removing lbp: 96.91 (-0.7353)
# Accuracy after removing spectral_energy: 97.50 (-0.1471)
# Accuracy after removing spectral_entropy: 96.62 (-1.0294)
# - Removing feature: kurtosis improved accuracy to: 97.65 (0.00)
#
# -----------------------------------------------
# - Iteration: 3
# Accuracy with all features: 97.65
# Accuracy after removing mean: 97.65 (0.0000)
# Accuracy after removing variance: 97.43 (-0.2206)
# Accuracy after removing skewness: 97.13 (-0.5147)
# Accuracy after removing contrast: 96.10 (-1.5441)
# Accuracy after removing homogeneity: 97.65 (0.0000)
# Accuracy after removing energy: 97.65 (0.0000)
# Accuracy after removing correlation: 97.13 (-0.5147)
# Accuracy after removing lbp: 97.13 (-0.5147)
# Accuracy after removing spectral_energy: 97.50 (-0.1471)
# Accuracy after removing spectral_entropy: 96.91 (-0.7353)
# - Removing feature: energy improved accuracy to: 97.65 (0.00)
#
# -----------------------------------------------
# - Iteration: 4
# Accuracy with all features: 97.65
# Accuracy after removing mean: 97.65 (0.0000)
# Accuracy after removing variance: 97.50 (-0.1471)
# Accuracy after removing skewness: 97.35 (-0.2941)
# Accuracy after removing contrast: 96.25 (-1.3971)
# Accuracy after removing homogeneity: 97.13 (-0.5147)
# Accuracy after removing correlation: 96.91 (-0.7353)
# Accuracy after removing lbp: 96.99 (-0.6618)
# Accuracy after removing spectral_energy: 97.65 (0.0000)
# Accuracy after removing spectral_entropy: 96.84 (-0.8088)
# - Removing feature: spectral_energy improved accuracy to: 97.65 (0.00)
#
# -----------------------------------------------
# - Iteration: 5
# Accuracy with all features: 97.65
# Accuracy after removing mean: 97.65 (0.0000)
# Accuracy after removing variance: 97.50 (-0.1471)
# Accuracy after removing skewness: 97.35 (-0.2941)
# Accuracy after removing contrast: 96.25 (-1.3971)
# Accuracy after removing homogeneity: 97.13 (-0.5147)
# Accuracy after removing correlation: 96.91 (-0.7353)
# Accuracy after removing lbp: 96.99 (-0.6618)
# Accuracy after removing spectral_entropy: 96.84 (-0.8088)
# - Removing feature: mean improved accuracy to: 97.65 (0.00)
#
# -----------------------------------------------
# - Iteration: 6
# Accuracy with all features: 97.65
# Accuracy after removing variance: 97.50 (-0.1471)
# Accuracy after removing skewness: 97.50 (-0.1471)
# Accuracy after removing contrast: 96.62 (-1.0294)
# Accuracy after removing homogeneity: 97.28 (-0.3676)
# Accuracy after removing correlation: 96.91 (-0.7353)
# Accuracy after removing lbp: 97.13 (-0.5147)
# Accuracy after removing spectral_entropy: 96.99 (-0.6618)
# > Dataset_name:  X-SDD
# Best accuracy: 97.65
# Selected feature : ['variance', 'skewness', 'contrast', 'homogeneity', 'correlation', 'lbp', 'spectral_entropy']
# ------------------------------------------
#  Performing RFE on level after selected features
#
# -----------------------------------------------
# - Iteration: 1
# Accuracy with all features: 97.65
# Accuracy after removing _1_: 97.21 (-0.4412)
# Accuracy after removing _2_: 96.99 (-0.6618)
# Accuracy after removing _3_: 96.84 (-0.8088)
# Accuracy after removing _4_: 96.76 (-0.8824)
# Accuracy after removing _5_: 96.54 (-1.1029)
# ------------------------------------------
#  Performing RFE on levels
# > Dataset_name:  X-SDD
# Best accuracy: 97.65
# Selected level : ['_1_', '_2_', '_3_', '_4_', '_5_']
# ---------------------------------------
# Individiual level accuracy on selected features:
# > Dataset_name:  X-SDD
#  - Level: _1_ Individual accuracy: 71.62
#  - Level: _2_ Individual accuracy: 84.71
#  - Level: _3_ Individual accuracy: 92.94
#  - Level: _4_ Individual accuracy: 95.59
#  - Level: _5_ Individual accuracy: 95.37
# ---------------------------------------

# %%
# Evaluate the selected features on level importance
from features_analysis import *    
dataset_name = 'NEU-CLS'
df, feature_names, labels = load_data(dataset_name)
iteration_number = 1
fold = 10

print("------------------------------------------")
print(" Performing RFE on features ")
# Perform RFE to select the best features combination on selected levels
best_accuracy, feature_types, selected_features = rfe(df, labels, initial_feature_types, iteration_number, fold)

print("> Dataset_name: ", dataset_name)
print(f"Best accuracy: {best_accuracy*100:.2f}")
print(f"Selected feature : {feature_types}")

print("------------------------------------------")
print(" Performing RFE on level after selected features ")
level_feature_types = ['_1_', '_2_', '_3_', '_4_', '_5_']

# Perform RFE to select the best level combination
best_accuracy, feature_types, selected_features = rfe(selected_features, labels, level_feature_types, iteration_number, fold)

print("------------------------------------------")
print(" Performing RFE on levels on selected features")
print("> Dataset_name: ", dataset_name)
print(f"Best accuracy: {best_accuracy*100:.2f}")
print(f"Selected level types: {feature_types}")

levels = ['_1_', '_2_', '_3_', '_4_', '_5_']
# Train the model with selected features in one level
print("---------------------------------------")
print("Individiual level accuracy")
print("> Dataset_name: ", dataset_name)
# Train the model for each level with all features combined
for level in levels:
    df_isolated = isolate_level_features(selected_features, level=level)
    acc = train(df_isolated, labels, fold)
    print(f" - Level: {level} Individual accuracy: {acc*100:.2f}")
    
print("---------------------------------------")
# Out:
# ------------------------------------------
#  Performing RFE on features
#
# -----------------------------------------------
# - Iteration: 1
# Accuracy with all features: 99.17
# Accuracy after removing mean: 99.06 (-0.1111)
# Accuracy after removing variance: 99.17 (0.0000)
# Accuracy after removing skewness: 99.22 (0.0556)
# Accuracy after removing kurtosis: 99.17 (0.0000)
# Accuracy after removing contrast: 99.11 (-0.0556)
# Accuracy after removing dissimilarity: 99.11 (-0.0556)
# Accuracy after removing homogeneity: 99.11 (-0.0556)
# Accuracy after removing energy: 99.33 (0.1667)
# Accuracy after removing correlation: 98.94 (-0.2222)
# Accuracy after removing lbp: 99.00 (-0.1667)
# Accuracy after removing spectral_energy: 99.17 (0.0000)
# Accuracy after removing spectral_entropy: 99.00 (-0.1667)
# - Removing feature: energy improved accuracy to: 99.33 (0.17)
#
# -----------------------------------------------
# - Iteration: 2
# Accuracy with all features: 99.33
# Accuracy after removing mean: 99.22 (-0.1111)
# Accuracy after removing variance: 99.22 (-0.1111)
# Accuracy after removing skewness: 99.39 (0.0556)
# Accuracy after removing kurtosis: 99.33 (0.0000)
# Accuracy after removing contrast: 99.28 (-0.0556)
# Accuracy after removing dissimilarity: 99.28 (-0.0556)
# Accuracy after removing homogeneity: 99.33 (0.0000)
# Accuracy after removing correlation: 99.11 (-0.2222)
# Accuracy after removing lbp: 99.17 (-0.1667)
# Accuracy after removing spectral_energy: 99.33 (0.0000)
# Accuracy after removing spectral_entropy: 99.11 (-0.2222)
# - Removing feature: skewness improved accuracy to: 99.39 (0.06)
#
# -----------------------------------------------
# - Iteration: 3
# Accuracy with all features: 99.39
# Accuracy after removing mean: 99.33 (-0.0556)
# Accuracy after removing variance: 99.28 (-0.1111)
# Accuracy after removing kurtosis: 99.28 (-0.1111)
# Accuracy after removing contrast: 99.28 (-0.1111)
# Accuracy after removing dissimilarity: 99.28 (-0.1111)
# Accuracy after removing homogeneity: 99.39 (0.0000)
# Accuracy after removing correlation: 99.17 (-0.2222)
# Accuracy after removing lbp: 99.22 (-0.1667)
# Accuracy after removing spectral_energy: 99.39 (0.0000)
# Accuracy after removing spectral_entropy: 99.22 (-0.1667)
# - Removing feature: spectral_energy improved accuracy to: 99.39 (0.00)
#
# -----------------------------------------------
# - Iteration: 4
# Accuracy with all features: 99.39
# Accuracy after removing mean: 99.33 (-0.0556)
# Accuracy after removing variance: 99.28 (-0.1111)
# Accuracy after removing kurtosis: 99.28 (-0.1111)
# Accuracy after removing contrast: 99.28 (-0.1111)
# Accuracy after removing dissimilarity: 99.28 (-0.1111)
# Accuracy after removing homogeneity: 99.39 (0.0000)
# Accuracy after removing correlation: 99.17 (-0.2222)
# Accuracy after removing lbp: 99.22 (-0.1667)
# Accuracy after removing spectral_entropy: 99.22 (-0.1667)
# - Removing feature: homogeneity improved accuracy to: 99.39 (0.00)
#
# -----------------------------------------------
# - Iteration: 5
# Accuracy with all features: 99.39
# Accuracy after removing mean: 99.28 (-0.1111)
# Accuracy after removing variance: 99.33 (-0.0556)
# Accuracy after removing kurtosis: 99.28 (-0.1111)
# Accuracy after removing contrast: 99.33 (-0.0556)
# Accuracy after removing dissimilarity: 99.28 (-0.1111)
# Accuracy after removing correlation: 99.22 (-0.1667)
# Accuracy after removing lbp: 99.28 (-0.1111)
# Accuracy after removing spectral_entropy: 99.22 (-0.1667)
# > Dataset_name:  NEU-CLS
# Best accuracy: 99.39
# Selected feature : ['mean', 'variance', 'kurtosis', 'contrast', 'dissimilarity', 'correlation', 'lbp', 'spectral_entropy']
# ------------------------------------------
#  Performing RFE on level after selected features
#
# -----------------------------------------------
# - Iteration: 1
# Accuracy with all features: 99.39
# Accuracy after removing _1_: 99.39 (-0.0000)
# Accuracy after removing _2_: 99.11 (-0.2778)
# Accuracy after removing _3_: 99.33 (-0.0556)
# Accuracy after removing _4_: 99.11 (-0.2778)
# Accuracy after removing _5_: 98.89 (-0.5000)
# ------------------------------------------
#  Performing RFE on levels on selected features
# > Dataset_name:  NEU-CLS
# Best accuracy: 99.39
# Selected level types: ['_1_', '_2_', '_3_', '_4_', '_5_']
# ---------------------------------------
# Individiual level accuracy
# > Dataset_name:  NEU-CLS
#  - Level: _1_ Individual accuracy: 76.56
#  - Level: _2_ Individual accuracy: 89.33
#  - Level: _3_ Individual accuracy: 96.17
#  - Level: _4_ Individual accuracy: 98.33
#  - Level: _5_ Individual accuracy: 98.44
# ---------------------------------------

# %%
from models import features_types
from features_analysis import load_data, select_features, isolate_level_features, train

dataset_name = 'NEU-CLS'
fold = 10

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types)

levels = ['_1_', '_2_', '_3_', '_4_', '_5_']
# Train the model with selected features in one level
print("---------------------------------------")
print("Individiual level accuracy")
print("> Dataset_name: ", dataset_name)
# Train the model for each level with all features combined
for level in levels:
    df_isolated = isolate_level_features(selected_df, level=level)
    acc = train(df_isolated.values, labels, fold)
    print(f" - Level: {level} individual accuracy: {acc*100:.2f}")

# Train the model for each level with all features combined
acc = train(selected_df.values, labels, fold)
print(f" - All levels combined accuracy: {acc*100:.2f}")
    
print("---------------------------------------")
# Out:
# ---------------------------------------
# Individiual level accuracy
# > Dataset_name:  NEU-CLS
#  - Level: _1_ individual accuracy: 76.56
#  - Level: _2_ individual accuracy: 89.33
#  - Level: _3_ individual accuracy: 96.17
#  - Level: _4_ individual accuracy: 98.33
#  - Level: _5_ individual accuracy: 98.44
#  - All levels combined accuracy: 99.39
# ---------------------------------------

# %%
from models import features_types
from features_analysis import load_data, select_features, isolate_level_features, train, train_grid_search

dataset_name = 'X-SDD'
fold = 10

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types)

levels = ['_1_', '_2_', '_3_', '_4_', '_5_']
# Train the model with selected features in one level
print("---------------------------------------")
print("Individiual level accuracy")
print("> Dataset_name: ", dataset_name)
# Train the model for each level with all features combined
for level in levels:
    df_isolated = isolate_level_features(selected_df, level=level)
    acc = train(df_isolated.values, labels, fold)
    print(f" - Level: {level} individual accuracy: {acc*100:.2f}")

# Train the model for each level with all features combined
acc = train_grid_search(selected_df.values, labels, fold)
print(f" - All levels combined accuracy: {acc*100:.2f}")
    
print("---------------------------------------")
# Out:
# ---------------------------------------
# Individiual level accuracy
# > Dataset_name:  X-SDD
#  - Level: _1_ individual accuracy: 70.37
#  - Level: _2_ individual accuracy: 84.34
#  - Level: _3_ individual accuracy: 91.25
#  - Level: _4_ individual accuracy: 95.00
#  - Level: _5_ individual accuracy: 95.29
#  - All levels combined accuracy: 98.16
# ---------------------------------------

# %%
from features_analysis import * 

dataset_name = 'X-SDD'
df, feature_names, labels = load_selected_features(dataset_name)
fold = 10


acc = train_grid_search(df.values, labels, fold)
print("------------------------------------------")
print(" Evaluate with selected features:")
print("> Dataset_name: ", dataset_name)
print(f"Accuracy: {acc*100:.2f}")
print(f"Feature length: {len(df.columns)}")
# Out:
# ------------------------------------------
#  Evaluate with selected features:
# > Dataset_name:  X-SDD
# Accuracy: 98.09
# Feature length: 242

# %%
from features_analysis import * 

dataset_name = 'NEU-CLS'
df, feature_names, labels = load_selected_features(dataset_name)
fold = 10


acc = train_grid_search(df.values, labels, fold)
print("------------------------------------------")
print(" Evaluate with selected features:")
print("> Dataset_name: ", dataset_name)
print(f"Accuracy: {acc*100:.2f}")
print(f"Feature length: {len(df.columns)}")
# Out:
# ------------------------------------------
#  Evaluate with selected features:
# > Dataset_name:  NEU-CLS
# Accuracy: 99.50
# Feature length: 258

# %%
from features_analysis import * 

features_types = ['mean', 'variance', 'kurtosis', 'contrast', 'dissimilarity', 
                  'correlation', 'lbp', 'spectral_entropy']

dataset_name = 'X-SDD'
df, feature_names, labels = load_data(dataset_name)
fold = 10

selected_df = select_features(df, features_types)
acc = train_grid_search(selected_df.values, labels, fold)

print("------------------------------------------")
print(f" > Dataset name: {dataset_name}")
print(f" - Accuracy: {acc*100:.2f}")
print(f' - Number of features: {selected_df.shape[1]}')
# Out:
# ------------------------------------------
#  > Dataset name: X-SDD
#  - Accuracy: 98.16
#  - Number of features: 258

# %%
from features_analysis import * 

features_types = ['mean', 'variance', 'kurtosis', 'contrast', 'dissimilarity', 
                  'correlation', 'lbp', 'spectral_entropy']

dataset_name = 'NEU-CLS'
df, feature_names, labels = load_data(dataset_name)
fold = 5

selected_df = select_features(df, features_types)
acc = train_grid_search(selected_df.values, labels, fold)

print("------------------------------------------")
print(f" > Dataset name: {dataset_name}")
print(f" - Accuracy: {acc*100:.2f}")
print(f' - Number of features: {selected_df.shape[1]}')
# Out:
# ------------------------------------------
#  > Dataset name: NEU-CLS
#  - Accuracy: 99.50
#  - Number of features: 258
