# %%
from models import *
from features_analysis import load_data, select_features

dataset_name = 'NEU-CLS'
fold = 10

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_neu)
results = svm_model(selected_df.values, labels, fold)


best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores, all_confusion_matrices = results

print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 100.00 % - Loss: 0.0232 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.44 % - Loss: 0.0440 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0239 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.44 % - Loss: 0.0421 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.0254 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.0290 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0281 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 99.44 % - Loss: 0.0323 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 100.00 % - Loss: 0.0219 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.89 % - Loss: 0.0573 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 10, 'gamma': 0.01}
# > Accuracy: 99.67 (+- 0.37)
# > Loss: 0.0327
# > Precision: 99.68 (+- 0.35)
# > Recall: 99.67 (+- 0.37)
# > F1 Score: 99.67 (+- 0.37)
# ----------------------------------------------------------------

# %%
from models import *
from features_analysis import load_data, select_features

dataset_name = 'NEU-CLS'
fold = 10

df, feature_names, labels = load_data(dataset_name)
selected_features = select_features(df, features_types_neu)

results = random_forest_model(selected_features.values, labels, n_folds=fold)
best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results

print_results(dataset_name, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.33 % - Loss: 0.1208 - Precision: 98.42 % - Recall: 98.33 % - F1 Score: 98.33 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 98.89 % - Loss: 0.0969 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0842 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 98.89 % - Loss: 0.0944 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.0960 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 98.89 % - Loss: 0.0949 - Precision: 98.89 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 98.33 % - Loss: 0.0999 - Precision: 98.48 % - Recall: 98.33 % - F1 Score: 98.33 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 98.89 % - Loss: 0.0947 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 98.89 % - Loss: 0.0958 - Precision: 98.89 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.89 % - Loss: 0.0813 - Precision: 98.91 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# > Accuracy: 99.00 (+- 0.54)
# > Loss: 0.0959
# > Precision: 99.05 (+- 0.51)
# > Recall: 99.00 (+- 0.54)
# > F1 Score: 99.00 (+- 0.54)
# ----------------------------------------------------------------

# %%
from models import *
from features_analysis import load_data, select_features

dataset_name = 'NEU-CLS'
fold = 10
batch_size = 16
epochs= 15
dropout_rate = 0.5


df, feature_names, labels = load_data(dataset_name)

selected_features = select_features(df, features_types_neu)

results = mlp_model(selected_features.values, labels, n_folds=fold, 
                    batch_size=batch_size, epochs=epochs, dropout_rate=dropout_rate)

acc_scores, loss_scores, recall_scores, precision_scores, f1_scores, fold_histories = results
print_results(dataset_name, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores)
plot_results(fold_histories)
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 62)]              0
#
#  dense_27 (Dense)            (None, 128)               8064
#
#  dense_28 (Dense)            (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_29 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 16,710
# Trainable params: 16,710
# Non-trainable params: 0
# _________________________________________________________________
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.89 % - Loss: 0.0373 - Precision: 98.89 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 98.89 % - Loss: 0.0490 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0050 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.44 % - Loss: 0.0129 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.0059 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.0044 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0177 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 100.00 % - Loss: 0.0023 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.44 % - Loss: 0.0204 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 99.44 % - Loss: 0.0210 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# > Accuracy: 99.56 (+- 0.42)
# > Loss: 0.0176
# > Precision: 99.57 (+- 0.40)
# > Recall: 99.56 (+- 0.42)
# > F1 Score: 99.56 (+- 0.41)
# ----------------------------------------------------------------

# %%
from models import *
from features_analysis import load_data, select_features


dataset_name = 'X-SDD'
fold = 10

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_xsdd)
results = svm_model(selected_df.values, labels, fold)


best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results

print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.26 % - Loss: 0.0872 - Precision: 99.43 % - Recall: 97.62 % - F1 Score: 98.41 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 96.32 % - Loss: 0.1232 - Precision: 96.77 % - Recall: 90.66 % - F1 Score: 92.38 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.26 % - Loss: 0.0742 - Precision: 97.96 % - Recall: 99.40 % - F1 Score: 98.60 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 97.06 % - Loss: 0.1296 - Precision: 97.35 % - Recall: 94.29 % - F1 Score: 95.31 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.79 % - Loss: 0.0973 - Precision: 97.70 % - Recall: 97.21 % - F1 Score: 97.34 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 97.79 % - Loss: 0.1243 - Precision: 97.62 % - Recall: 97.47 % - F1 Score: 97.49 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 98.53 % - Loss: 0.1038 - Precision: 98.72 % - Recall: 95.92 % - F1 Score: 96.97 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 98.53 % - Loss: 0.0866 - Precision: 99.06 % - Recall: 97.79 % - F1 Score: 98.37 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.26 % - Loss: 0.0570 - Precision: 99.43 % - Recall: 98.98 % - F1 Score: 99.18 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.53 % - Loss: 0.0651 - Precision: 98.37 % - Recall: 98.95 % - F1 Score: 98.62 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 98.24 (+- 0.94)
# > Loss: 0.0948
# > Precision: 98.24 (+- 0.86)
# > Recall: 96.83 (+- 2.51)
# > F1 Score: 97.27 (+- 1.94)
# ----------------------------------------------------------------

# %%
from models import *
from features_analysis import load_data, select_features

dataset_name = 'X-SDD'
fold = 10

df, feature_names, labels = load_data(dataset_name)
selected_features = select_features(df, features_types_xsdd)

results = random_forest_model(selected_features.values, labels, n_folds=fold)
best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results

print_results(dataset_name, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 96.32 % - Loss: 0.2826 - Precision: 96.90 % - Recall: 92.45 % - F1 Score: 94.06 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 95.59 % - Loss: 0.2811 - Precision: 96.56 % - Recall: 92.00 % - F1 Score: 93.75 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 94.12 % - Loss: 0.3190 - Precision: 94.15 % - Recall: 90.81 % - F1 Score: 91.97 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 96.32 % - Loss: 0.2598 - Precision: 96.22 % - Recall: 94.17 % - F1 Score: 94.54 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 96.32 % - Loss: 0.2864 - Precision: 97.73 % - Recall: 90.66 % - F1 Score: 92.91 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 98.53 % - Loss: 0.2476 - Precision: 98.41 % - Recall: 95.92 % - F1 Score: 96.80 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 97.06 % - Loss: 0.2304 - Precision: 97.78 % - Recall: 95.13 % - F1 Score: 96.31 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 95.59 % - Loss: 0.2864 - Precision: 96.43 % - Recall: 92.33 % - F1 Score: 93.91 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 94.12 % - Loss: 0.2836 - Precision: 94.06 % - Recall: 87.47 % - F1 Score: 88.31 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 97.79 % - Loss: 0.2605 - Precision: 98.41 % - Recall: 95.41 % - F1 Score: 96.71 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# > Accuracy: 96.18 (+- 1.35)
# > Loss: 0.2737
# > Precision: 96.66 (+- 1.48)
# > Recall: 92.63 (+- 2.48)
# > F1 Score: 93.93 (+- 2.42)
# ----------------------------------------------------------------

# %%
from models import *
from features_analysis import load_data, select_features

dataset_name = 'X-SDD'
fold = 10
batch_size = 16
epochs= 15
dropout_rate = 0.3


df, feature_names, labels = load_data(dataset_name)

selected_features = select_features(df, features_types_xsdd)

results = mlp_model(selected_features.values, labels, n_folds=fold, 
                    batch_size=batch_size, epochs=epochs, dropout_rate=dropout_rate)

acc_scores, loss_scores, recall_scores, precision_scores, f1_scores, fold_histories = results
print_results(dataset_name, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores)
plot_results(fold_histories)
# Out:
# Restoring model weights from the end of the best epoch: 5.
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Epoch 15: early stopping
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 273)]             0
#
#  dense_57 (Dense)            (None, 128)               35072
#
#  dense_58 (Dense)            (None, 64)                8256
#
#  dropout_19 (Dropout)        (None, 64)                0
#
#  dense_59 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 43,783
# Trainable params: 43,783
# Non-trainable params: 0
# _________________________________________________________________
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 96.32 % - Loss: 0.1426 - Precision: 97.41 % - Recall: 92.27 % - F1 Score: 94.25 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 96.32 % - Loss: 0.1017 - Precision: 97.18 % - Recall: 94.29 % - F1 Score: 95.55 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 97.06 % - Loss: 0.1600 - Precision: 96.58 % - Recall: 94.05 % - F1 Score: 94.78 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 96.32 % - Loss: 0.1322 - Precision: 96.57 % - Recall: 96.88 % - F1 Score: 96.70 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.79 % - Loss: 0.0386 - Precision: 96.46 % - Recall: 94.64 % - F1 Score: 95.45 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 98.53 % - Loss: 0.0345 - Precision: 97.88 % - Recall: 97.36 % - F1 Score: 97.50 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.26 % - Loss: 0.0248 - Precision: 99.65 % - Recall: 98.81 % - F1 Score: 99.20 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 98.53 % - Loss: 0.0691 - Precision: 98.86 % - Recall: 97.79 % - F1 Score: 98.25 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 97.06 % - Loss: 0.1274 - Precision: 94.30 % - Recall: 93.45 % - F1 Score: 93.75 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.53 % - Loss: 0.0897 - Precision: 98.90 % - Recall: 97.79 % - F1 Score: 98.28 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# > Accuracy: 97.57 (+- 1.04)
# > Loss: 0.0921
# > Precision: 97.38 (+- 1.47)
# > Recall: 95.73 (+- 2.13)
# > F1 Score: 96.37 (+- 1.79)
# ----------------------------------------------------------------

# %%
# evaluate with different K-fold
from models import *
from features_analysis import load_data, select_features

dataset_name = 'NEU-CLS'


df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_neu)

# K-fold = 10
fold = 10
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)


# K-fold = 5
fold = 5
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# K-fold = 4
fold = 4
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# K-fold = 3
fold = 3
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# K-fold = 2
fold = 2
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
#  *-* Performance on K-fold = 10 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 100.00 % - Loss: 0.0231 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.44 % - Loss: 0.0447 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0246 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.44 % - Loss: 0.0409 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.0255 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.0285 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0296 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 99.44 % - Loss: 0.0319 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 100.00 % - Loss: 0.0211 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.89 % - Loss: 0.0561 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 10, 'gamma': 0.01}
# > Accuracy: 99.67 (+- 0.37)
# > Loss: 0.0326
# > Precision: 99.68 (+- 0.35)
# > Recall: 99.67 (+- 0.37)
# > F1 Score: 99.67 (+- 0.37)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 5 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.61 % - Loss: 0.0533 - Precision: 98.67 % - Recall: 98.61 % - F1 Score: 98.61 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.44 % - Loss: 0.0472 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.45 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0320 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.44 % - Loss: 0.0333 - Precision: 99.45 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 99.72 % - Loss: 0.0384 - Precision: 99.73 % - Recall: 99.72 % - F1 Score: 99.72 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 1, 'gamma': 0.01}
# > Accuracy: 99.44 (+- 0.46)
# > Loss: 0.0408
# > Precision: 99.46 (+- 0.45)
# > Recall: 99.44 (+- 0.46)
# > F1 Score: 99.44 (+- 0.47)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 4 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.11 % - Loss: 0.0485 - Precision: 99.13 % - Recall: 99.11 % - F1 Score: 99.11 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.56 % - Loss: 0.0465 - Precision: 99.56 % - Recall: 99.56 % - F1 Score: 99.56 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.56 % - Loss: 0.0337 - Precision: 99.57 % - Recall: 99.56 % - F1 Score: 99.56 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.56 % - Loss: 0.0420 - Precision: 99.57 % - Recall: 99.56 % - F1 Score: 99.56 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 1, 'gamma': 'scale'}
# > Accuracy: 99.44 (+- 0.19)
# > Loss: 0.0427
# > Precision: 99.46 (+- 0.19)
# > Recall: 99.44 (+- 0.19)
# > F1 Score: 99.44 (+- 0.19)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 3 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.33 % - Loss: 0.0504 - Precision: 99.34 % - Recall: 99.33 % - F1 Score: 99.33 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.50 % - Loss: 0.0459 - Precision: 99.50 % - Recall: 99.50 % - F1 Score: 99.50 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.50 % - Loss: 0.0385 - Precision: 99.51 % - Recall: 99.50 % - F1 Score: 99.50 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 1, 'gamma': 'scale'}
# > Accuracy: 99.44 (+- 0.08)
# > Loss: 0.0449
# > Precision: 99.45 (+- 0.08)
# > Recall: 99.44 (+- 0.08)
# > F1 Score: 99.44 (+- 0.08)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 2 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.22 % - Loss: 0.0583 - Precision: 99.23 % - Recall: 99.22 % - F1 Score: 99.22 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.56 % - Loss: 0.0432 - Precision: 99.56 % - Recall: 99.56 % - F1 Score: 99.56 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 10, 'gamma': 0.01}
# > Accuracy: 99.39 (+- 0.17)
# > Loss: 0.0507
# > Precision: 99.40 (+- 0.17)
# > Recall: 99.39 (+- 0.17)
# > F1 Score: 99.39 (+- 0.17)
# ----------------------------------------------------------------

# %%
# evaluate with different K-fold
from models import *
from features_analysis import load_data, select_features

dataset_name = 'X-SDD'


df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_xsdd)

# K-fold = 10
fold = 10
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)


# K-fold = 5
fold = 5
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# K-fold = 4
fold = 4
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# K-fold = 3
fold = 3
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# K-fold = 2
fold = 2
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
#  *-* Performance on K-fold = 10 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.26 % - Loss: 0.0871 - Precision: 99.43 % - Recall: 97.62 % - F1 Score: 98.41 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 96.32 % - Loss: 0.1238 - Precision: 96.77 % - Recall: 90.66 % - F1 Score: 92.38 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.26 % - Loss: 0.0728 - Precision: 97.96 % - Recall: 99.40 % - F1 Score: 98.60 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 97.06 % - Loss: 0.1304 - Precision: 97.35 % - Recall: 94.29 % - F1 Score: 95.31 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.79 % - Loss: 0.0953 - Precision: 97.70 % - Recall: 97.21 % - F1 Score: 97.34 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 97.79 % - Loss: 0.1242 - Precision: 97.62 % - Recall: 97.47 % - F1 Score: 97.49 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 98.53 % - Loss: 0.1040 - Precision: 98.72 % - Recall: 95.92 % - F1 Score: 96.97 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 98.53 % - Loss: 0.0849 - Precision: 99.06 % - Recall: 97.79 % - F1 Score: 98.37 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.26 % - Loss: 0.0570 - Precision: 99.43 % - Recall: 98.98 % - F1 Score: 99.18 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.53 % - Loss: 0.0638 - Precision: 98.37 % - Recall: 98.95 % - F1 Score: 98.62 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 98.24 (+- 0.94)
# > Loss: 0.0943
# > Precision: 98.24 (+- 0.86)
# > Recall: 96.83 (+- 2.51)
# > F1 Score: 97.27 (+- 1.94)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 5 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 97.43 % - Loss: 0.1146 - Precision: 97.53 % - Recall: 94.21 % - F1 Score: 95.41 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 98.53 % - Loss: 0.1082 - Precision: 97.67 % - Recall: 98.11 % - F1 Score: 97.88 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 97.43 % - Loss: 0.1170 - Precision: 97.26 % - Recall: 94.68 % - F1 Score: 95.73 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 100.00 % - Loss: 0.0777 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 98.90 % - Loss: 0.0749 - Precision: 99.00 % - Recall: 98.72 % - F1 Score: 98.85 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 98.46 (+- 0.97)
# > Loss: 0.0985
# > Precision: 98.29 (+- 1.04)
# > Recall: 97.14 (+- 2.29)
# > F1 Score: 97.58 (+- 1.77)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 4 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 97.35 % - Loss: 0.1079 - Precision: 97.21 % - Recall: 94.74 % - F1 Score: 95.81 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 97.94 % - Loss: 0.1061 - Precision: 97.93 % - Recall: 96.64 % - F1 Score: 97.21 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 97.94 % - Loss: 0.1015 - Precision: 98.54 % - Recall: 95.67 % - F1 Score: 96.92 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 98.82 % - Loss: 0.0869 - Precision: 98.88 % - Recall: 98.56 % - F1 Score: 98.70 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 10, 'gamma': 'scale'}
# > Accuracy: 98.01 (+- 0.53)
# > Loss: 0.1006
# > Precision: 98.14 (+- 0.63)
# > Recall: 96.40 (+- 1.41)
# > F1 Score: 97.16 (+- 1.03)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 3 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.24 % - Loss: 0.1120 - Precision: 97.31 % - Recall: 96.25 % - F1 Score: 96.74 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 97.13 % - Loss: 0.1273 - Precision: 97.22 % - Recall: 95.14 % - F1 Score: 96.03 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 98.90 % - Loss: 0.0880 - Precision: 99.00 % - Recall: 98.70 % - F1 Score: 98.84 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 98.09 (+- 0.73)
# > Loss: 0.1091
# > Precision: 97.85 (+- 0.82)
# > Recall: 96.70 (+- 1.48)
# > F1 Score: 97.21 (+- 1.19)
# ----------------------------------------------------------------
#  *-* Performance on K-fold = 2 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 96.62 % - Loss: 0.1361 - Precision: 96.31 % - Recall: 93.46 % - F1 Score: 94.61 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 97.79 % - Loss: 0.1207 - Precision: 97.94 % - Recall: 96.91 % - F1 Score: 97.40 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 97.21 (+- 0.59)
# > Loss: 0.1284
# > Precision: 97.12 (+- 0.81)
# > Recall: 95.19 (+- 1.72)
# > F1 Score: 96.00 (+- 1.40)
# ----------------------------------------------------------------

# %%
# evaluate with different K-fold
from models import *
from features_analysis import load_data, select_features

dataset_name = 'NEU-CLS'


df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_xsdd)

# K-fold = 10
fold = 10
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
#  *-* Performance on K-fold = 10 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.44 % - Loss: 0.0321 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 98.89 % - Loss: 0.0477 - Precision: 98.89 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0214 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 98.89 % - Loss: 0.0597 - Precision: 98.92 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 99.44 % - Loss: 0.0267 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 99.44 % - Loss: 0.0355 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0241 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 100.00 % - Loss: 0.0235 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.44 % - Loss: 0.0443 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 99.44 % - Loss: 0.0415 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 99.44 (+- 0.35)
# > Loss: 0.0356
# > Precision: 99.46 (+- 0.35)
# > Recall: 99.44 (+- 0.35)
# > F1 Score: 99.44 (+- 0.35)
# ----------------------------------------------------------------

# %%
# evaluate with different K-fold
from models import *
from features_analysis import load_data, select_features

dataset_name = 'X-SDD'


df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_neu)

# K-fold = 10
fold = 10
results = svm_model(selected_df.values, labels, fold)

best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores = results
print(f" *-* Performance on K-fold = {fold} *-*")
print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)
# Out:
#  *-* Performance on K-fold = 10 *-*
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 97.79 % - Loss: 0.1159 - Precision: 97.66 % - Recall: 95.92 % - F1 Score: 96.63 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 94.85 % - Loss: 0.1318 - Precision: 94.97 % - Recall: 90.06 % - F1 Score: 91.92 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 97.79 % - Loss: 0.1018 - Precision: 96.21 % - Recall: 97.71 % - F1 Score: 96.80 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 97.79 % - Loss: 0.1091 - Precision: 98.07 % - Recall: 94.14 % - F1 Score: 95.58 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.06 % - Loss: 0.1164 - Precision: 97.16 % - Recall: 96.11 % - F1 Score: 96.38 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 97.06 % - Loss: 0.1499 - Precision: 96.25 % - Recall: 95.81 % - F1 Score: 95.82 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 97.06 % - Loss: 0.1190 - Precision: 97.70 % - Recall: 92.86 % - F1 Score: 94.40 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 96.32 % - Loss: 0.1394 - Precision: 96.11 % - Recall: 95.83 % - F1 Score: 95.95 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 95.59 % - Loss: 0.1349 - Precision: 94.98 % - Recall: 95.09 % - F1 Score: 95.01 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 97.06 % - Loss: 0.1075 - Precision: 95.99 % - Recall: 95.71 % - F1 Score: 95.83 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 100, 'gamma': 0.01}
# > Accuracy: 96.84 (+- 0.93)
# > Loss: 0.1226
# > Precision: 96.51 (+- 1.04)
# > Recall: 94.92 (+- 2.02)
# > F1 Score: 95.43 (+- 1.36)
# ----------------------------------------------------------------

# %%
from models import *
from data_preprocessing import get_data
from features_analysis import load_data, select_features

dataset_name = 'NEU-CLS'
fold = 10

data, labels, target_dict = get_data(dataset_name)
# Reverse the target_dict to get class names by their indices
target_dict = {v: k for k, v in target_dict.items()}
# Get class names sorted by class index
class_names = [target_dict[i] for i in sorted(target_dict.keys())]

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_neu)
results = svm_model(selected_df.values, labels, fold)


best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores, all_confusion_matrices = results

print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# Average confusion matrix over all folds
average_cm_neu = np.mean(all_confusion_matrices, axis=0)
# Out:
# Loading preprocessed data for NEU-CLS.
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 100.00 % - Loss: 0.0246 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.44 % - Loss: 0.0436 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0253 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.44 % - Loss: 0.0420 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.0250 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.0292 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0301 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 99.44 % - Loss: 0.0331 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 100.00 % - Loss: 0.0209 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.89 % - Loss: 0.0585 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Classifier parameters:  {'C': 10, 'gamma': 0.01}
# > Accuracy: 99.67 (+- 0.37)
# > Loss: 0.0332
# > Precision: 99.68 (+- 0.35)
# > Recall: 99.67 (+- 0.37)
# > F1 Score: 99.67 (+- 0.37)
# ----------------------------------------------------------------

# %%
dataset_name = 'NEU-CLS'
class_names = ['Cr', 'In', 'Ps', 'Pa', 'Rs', 'Sc']
plot_confusion_matrix(average_cm_neu, class_names, dataset_name=dataset_name,normalize=True)

# %%
from models import *
from data_preprocessing import get_data
from features_analysis import load_data, select_features

dataset_name = 'X-SDD'
fold = 10

data, labels, target_dict = get_data(dataset_name)
# Reverse the target_dict to get class names by their indices
target_dict = {v: k for k, v in target_dict.items()}
# Get class names sorted by class index
class_names = [target_dict[i] for i in sorted(target_dict.keys())]

df, feature_names, labels = load_data(dataset_name)

selected_df = select_features(df, features_types_xsdd)
results = svm_model(selected_df.values, labels, fold)


best_params, acc_scores, loss_scores, precision_scores, recall_scores, f1_scores, all_confusion_matrices = results

print_results(dataset_name, acc_scores, loss_scores, 
                precision_scores, recall_scores, f1_scores, best_params=best_params)

# Average confusion matrix over all folds
average_cm_xsdd = np.mean(all_confusion_matrices, axis=0)
# Out:
# Loading preprocessed data for X-SDD.
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.26 % - Loss: 0.0872 - Precision: 99.43 % - Recall: 97.62 % - F1 Score: 98.41 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 96.32 % - Loss: 0.1232 - Precision: 96.77 % - Recall: 90.66 % - F1 Score: 92.38 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.26 % - Loss: 0.0740 - Precision: 97.96 % - Recall: 99.40 % - F1 Score: 98.60 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 97.06 % - Loss: 0.1319 - Precision: 97.35 % - Recall: 94.29 % - F1 Score: 95.31 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.79 % - Loss: 0.0983 - Precision: 97.70 % - Recall: 97.21 % - F1 Score: 97.34 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 97.79 % - Loss: 0.1248 - Precision: 97.62 % - Recall: 97.47 % - F1 Score: 97.49 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 98.53 % - Loss: 0.1044 - Precision: 98.72 % - Recall: 95.92 % - F1 Score: 96.97 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 98.53 % - Loss: 0.0885 - Precision: 99.06 % - Recall: 97.79 % - F1 Score: 98.37 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.26 % - Loss: 0.0564 - Precision: 99.43 % - Recall: 98.98 % - F1 Score: 99.18 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.53 % - Loss: 0.0645 - Precision: 98.37 % - Recall: 98.95 % - F1 Score: 98.62 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Classifier parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 98.24 (+- 0.94)
# > Loss: 0.0953
# > Precision: 98.24 (+- 0.86)
# > Recall: 96.83 (+- 2.51)
# > F1 Score: 97.27 (+- 1.94)
# ----------------------------------------------------------------

# %%
dataset_name = 'X-SDD'
class_names = ['Finish R', 'Iron S', 'Oxide S P', 'Oxide S T', 'Red I', 'Slag I', 'Surface S']
plot_confusion_matrix(average_cm_xsdd, class_names, dataset_name=dataset_name,normalize=True)
