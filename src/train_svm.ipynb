# %%
from svm_wt_model import svm_wt_model, print_results

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 1
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature_vectors shape :  (1360, 37)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 97.79 % - Loss: 0.1468 - Precision: 95.92 % - Recall: 96.34 % - F1 Score: 96.10 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 94.12 % - Loss: 0.1777 - Precision: 95.75 % - Recall: 87.68 % - F1 Score: 90.26 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 95.59 % - Loss: 0.1358 - Precision: 93.65 % - Recall: 94.83 % - F1 Score: 93.80 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 95.59 % - Loss: 0.1648 - Precision: 93.83 % - Recall: 93.13 % - F1 Score: 93.39 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 96.32 % - Loss: 0.1213 - Precision: 96.71 % - Recall: 95.51 % - F1 Score: 95.84 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 96.32 % - Loss: 0.1467 - Precision: 95.44 % - Recall: 94.15 % - F1 Score: 94.64 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 95.59 % - Loss: 0.1503 - Precision: 96.15 % - Recall: 91.90 % - F1 Score: 93.51 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 94.12 % - Loss: 0.1526 - Precision: 94.24 % - Recall: 91.56 % - F1 Score: 92.29 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 98.53 % - Loss: 0.0918 - Precision: 99.07 % - Recall: 97.96 % - F1 Score: 98.43 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.53 % - Loss: 0.0930 - Precision: 96.43 % - Recall: 98.81 % - F1 Score: 97.34 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Level of decomposition :  1
# - SVM parameters:  {'C': 10, 'gamma': 0.01}
# > Accuracy: 96.25 (+- 1.52)
# > Loss: 0.1381
# > Precision: 95.72 (+- 1.52)
# > Recall: 94.19 (+- 3.13)
# > F1 Score: 94.56 (+- 2.31)
# ----------------------------------------------------------------

# %%
from svm_wt_model import svm_wt_model, print_results

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 2
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature_vectors shape :  (1360, 70)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.53 % - Loss: 0.1351 - Precision: 98.31 % - Recall: 97.02 % - F1 Score: 97.53 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 93.38 % - Loss: 0.1791 - Precision: 93.11 % - Recall: 87.18 % - F1 Score: 88.83 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 98.53 % - Loss: 0.1346 - Precision: 96.86 % - Recall: 98.69 % - F1 Score: 97.66 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 96.32 % - Loss: 0.1549 - Precision: 96.80 % - Recall: 93.19 % - F1 Score: 94.46 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.06 % - Loss: 0.1419 - Precision: 97.33 % - Recall: 96.61 % - F1 Score: 96.84 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 97.79 % - Loss: 0.1493 - Precision: 96.96 % - Recall: 97.00 % - F1 Score: 96.85 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 96.32 % - Loss: 0.1543 - Precision: 96.56 % - Recall: 92.92 % - F1 Score: 94.24 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 96.32 % - Loss: 0.1652 - Precision: 96.04 % - Recall: 95.25 % - F1 Score: 95.42 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 96.32 % - Loss: 0.0952 - Precision: 95.35 % - Recall: 95.81 % - F1 Score: 95.45 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 97.79 % - Loss: 0.1002 - Precision: 95.91 % - Recall: 98.44 % - F1 Score: 97.03 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Level of decomposition :  2
# - SVM parameters:  {'C': 100, 'gamma': 0.001}
# > Accuracy: 96.84 (+- 1.44)
# > Loss: 0.1410
# > Precision: 96.32 (+- 1.32)
# > Recall: 95.21 (+- 3.24)
# > F1 Score: 95.43 (+- 2.49)
# ----------------------------------------------------------------

# %%
from svm_wt_model import svm_wt_model, print_results

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 3
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature_vectors shape :  (1360, 103)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 97.79 % - Loss: 0.1118 - Precision: 97.95 % - Recall: 94.64 % - F1 Score: 95.80 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 95.59 % - Loss: 0.1407 - Precision: 96.19 % - Recall: 89.47 % - F1 Score: 91.49 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.26 % - Loss: 0.0854 - Precision: 97.96 % - Recall: 99.40 % - F1 Score: 98.60 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 96.32 % - Loss: 0.1504 - Precision: 96.81 % - Recall: 91.16 % - F1 Score: 92.74 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.79 % - Loss: 0.0880 - Precision: 97.70 % - Recall: 97.21 % - F1 Score: 97.34 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 97.06 % - Loss: 0.1436 - Precision: 95.99 % - Recall: 94.96 % - F1 Score: 95.41 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 94.12 % - Loss: 0.1417 - Precision: 95.63 % - Recall: 86.39 % - F1 Score: 87.95 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 97.79 % - Loss: 0.1336 - Precision: 98.38 % - Recall: 97.07 % - F1 Score: 97.65 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 97.79 % - Loss: 0.0925 - Precision: 98.54 % - Recall: 96.77 % - F1 Score: 97.53 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.53 % - Loss: 0.0820 - Precision: 96.43 % - Recall: 98.81 % - F1 Score: 97.34 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Level of decomposition :  3
# - SVM parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 97.21 (+- 1.43)
# > Loss: 0.1170
# > Precision: 97.16 (+- 1.01)
# > Recall: 94.59 (+- 4.05)
# > F1 Score: 95.18 (+- 3.24)
# ----------------------------------------------------------------

# %%
from svm_wt_model import svm_wt_model, print_results

dataset_name = 'X-SDD'
n_folds = 10
wavelet = 'haar'
level = 4
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature_vectors shape :  (1360, 136)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.53 % - Loss: 0.1165 - Precision: 98.31 % - Recall: 97.02 % - F1 Score: 97.53 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 95.59 % - Loss: 0.1409 - Precision: 95.81 % - Recall: 89.97 % - F1 Score: 91.63 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.26 % - Loss: 0.0752 - Precision: 97.96 % - Recall: 99.40 % - F1 Score: 98.60 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 95.59 % - Loss: 0.1443 - Precision: 93.85 % - Recall: 92.98 % - F1 Score: 93.26 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.79 % - Loss: 0.0880 - Precision: 97.70 % - Recall: 97.21 % - F1 Score: 97.34 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 98.53 % - Loss: 0.1398 - Precision: 97.64 % - Recall: 97.71 % - F1 Score: 97.56 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 95.59 % - Loss: 0.1387 - Precision: 97.18 % - Recall: 89.46 % - F1 Score: 91.53 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 97.06 % - Loss: 0.1241 - Precision: 97.83 % - Recall: 95.03 % - F1 Score: 96.26 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 97.79 % - Loss: 0.0905 - Precision: 97.67 % - Recall: 97.19 % - F1 Score: 97.41 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 99.26 % - Loss: 0.0703 - Precision: 97.96 % - Recall: 99.40 % - F1 Score: 98.60 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Level of decomposition :  4
# - SVM parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 97.50 (+- 1.40)
# > Loss: 0.1128
# > Precision: 97.19 (+- 1.29)
# > Recall: 95.54 (+- 3.42)
# > F1 Score: 95.97 (+- 2.62)
# ----------------------------------------------------------------

# %%
from svm_wt_model import svm_wt_model, print_results

dataset_name = 'X-SDD' 
n_folds = 10
wavelet = 'haar'
level = 5
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for X-SDD already exists.
# Loading preprocessed data for X-SDD.
# Number of data elements: 1360
# Number of classes: 7
# Classes and their corresponding indices: {'finishing roll printing': 0, 'iron sheet ash': 1, 'oxide scale of plate system': 2, 'oxide scale of temperature system': 3, 'red iron': 4, 'slag inclusion': 5, 'surface scratch': 6}
# Feature_vectors shape :  (1360, 169)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 97.79 % - Loss: 0.1152 - Precision: 95.92 % - Recall: 96.66 % - F1 Score: 96.27 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 97.06 % - Loss: 0.1279 - Precision: 97.12 % - Recall: 93.04 % - F1 Score: 94.46 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 98.53 % - Loss: 0.0777 - Precision: 96.86 % - Recall: 98.81 % - F1 Score: 97.71 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 97.79 % - Loss: 0.1128 - Precision: 97.70 % - Recall: 96.67 % - F1 Score: 97.05 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 97.06 % - Loss: 0.0894 - Precision: 96.79 % - Recall: 96.61 % - F1 Score: 96.53 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 98.53 % - Loss: 0.1233 - Precision: 97.64 % - Recall: 97.71 % - F1 Score: 97.56 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 97.06 % - Loss: 0.1162 - Precision: 97.83 % - Recall: 92.69 % - F1 Score: 94.36 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 97.79 % - Loss: 0.0974 - Precision: 96.94 % - Recall: 97.07 % - F1 Score: 96.88 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 97.06 % - Loss: 0.0848 - Precision: 95.80 % - Recall: 96.83 % - F1 Score: 96.20 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.53 % - Loss: 0.0725 - Precision: 97.02 % - Recall: 97.02 % - F1 Score: 97.02 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  X-SDD
# - Level of decomposition :  5
# - SVM parameters:  {'C': 10, 'gamma': 0.001}
# > Accuracy: 97.72 (+- 0.61)
# > Loss: 0.1017
# > Precision: 96.96 (+- 0.65)
# > Recall: 96.31 (+- 1.84)
# > F1 Score: 96.40 (+- 1.10)
# ----------------------------------------------------------------

# %%
dataset_name = 'NEU-CLS' 
n_folds = 10
wavelet = 'haar'
level = 1
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature_vectors shape :  (1800, 37)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.44 % - Loss: 0.0340 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 97.78 % - Loss: 0.0661 - Precision: 97.85 % - Recall: 97.78 % - F1 Score: 97.78 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 99.44 % - Loss: 0.0265 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 98.89 % - Loss: 0.0621 - Precision: 98.92 % - Recall: 98.89 % - F1 Score: 98.88 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 99.44 % - Loss: 0.0284 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 99.44 % - Loss: 0.0367 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0438 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 98.89 % - Loss: 0.0410 - Precision: 98.92 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 98.89 % - Loss: 0.0346 - Precision: 98.89 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 97.22 % - Loss: 0.0970 - Precision: 97.44 % - Recall: 97.22 % - F1 Score: 97.24 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Level of decomposition :  1
# - SVM parameters:  {'C': 10, 'gamma': 0.01}
# > Accuracy: 98.89 (+- 0.75)
# > Loss: 0.0470
# > Precision: 98.93 (+- 0.69)
# > Recall: 98.89 (+- 0.75)
# > F1 Score: 98.89 (+- 0.74)
# ----------------------------------------------------------------

# %%
dataset_name = 'NEU-CLS' 
n_folds = 10
wavelet = 'haar'
level = 2
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature_vectors shape :  (1800, 70)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.89 % - Loss: 0.0329 - Precision: 98.92 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.44 % - Loss: 0.0316 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0172 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 100.00 % - Loss: 0.0272 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.0219 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 99.44 % - Loss: 0.0312 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 100.00 % - Loss: 0.0229 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 100.00 % - Loss: 0.0226 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.44 % - Loss: 0.0557 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.89 % - Loss: 0.0428 - Precision: 98.91 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Level of decomposition :  2
# - SVM parameters:  {'C': 100, 'gamma': 0.01}
# > Accuracy: 99.61 (+- 0.43)
# > Loss: 0.0306
# > Precision: 99.62 (+- 0.42)
# > Recall: 99.61 (+- 0.43)
# > F1 Score: 99.61 (+- 0.43)
# ----------------------------------------------------------------

# %%
dataset_name = 'NEU-CLS' 
n_folds = 10
wavelet = 'haar'
level = 3
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature_vectors shape :  (1800, 103)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 99.44 % - Loss: 0.0388 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.44 % - Loss: 0.0339 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0206 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.44 % - Loss: 0.0503 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 99.44 % - Loss: 0.0251 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.0271 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0251 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 99.44 % - Loss: 0.0227 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.44 % - Loss: 0.0485 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 97.78 % - Loss: 0.0518 - Precision: 97.85 % - Recall: 97.78 % - F1 Score: 97.79 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Level of decomposition :  3
# - SVM parameters:  {'C': 10, 'gamma': 'scale'}
# > Accuracy: 99.39 (+- 0.58)
# > Loss: 0.0344
# > Precision: 99.41 (+- 0.56)
# > Recall: 99.39 (+- 0.58)
# > F1 Score: 99.39 (+- 0.58)
# ----------------------------------------------------------------

# %%
dataset_name = 'NEU-CLS' 
n_folds = 10
wavelet = 'haar'
level = 4
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature_vectors shape :  (1800, 136)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.89 % - Loss: 0.0472 - Precision: 98.91 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 99.44 % - Loss: 0.0473 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0189 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 98.89 % - Loss: 0.0562 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 99.44 % - Loss: 0.0247 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 100.00 % - Loss: 0.0229 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 99.44 % - Loss: 0.0268 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 99.44 % - Loss: 0.0251 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.44 % - Loss: 0.0484 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 97.78 % - Loss: 0.0596 - Precision: 97.85 % - Recall: 97.78 % - F1 Score: 97.79 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Level of decomposition :  4
# - SVM parameters:  {'C': 10, 'gamma': 'scale'}
# > Accuracy: 99.28 (+- 0.61)
# > Loss: 0.0377
# > Precision: 99.30 (+- 0.59)
# > Recall: 99.28 (+- 0.61)
# > F1 Score: 99.28 (+- 0.61)
# ----------------------------------------------------------------

# %%
dataset_name = 'NEU-CLS' 
n_folds = 10
wavelet = 'haar'
level = 5
results = svm_wt_model(dataset_name = dataset_name,
                        n_folds = n_folds,
                        wavelet = wavelet,
                        level = level)
(best_params, train_acc_scores, val_acc_scores, train_loss_scores, val_loss_scores, 
    precision_scores, recall_scores, f1_scores, misclassified_info) = results

print_results(dataset_name, level, best_params, val_acc_scores, val_loss_scores, 
                precision_scores, recall_scores, f1_scores)
# Out:
# Preprocessed data for NEU-CLS already exists.
# Loading preprocessed data for NEU-CLS.
# Number of data elements: 1800
# Number of classes: 6
# Classes and their corresponding indices: {'Cr': 0, 'In': 1, 'PS': 2, 'Pa': 3, 'RS': 4, 'Sc': 5}
# Feature_vectors shape :  (1800, 169)
# ----------------------------------------------------------------
# Score per fold
# -------------------------------------------------------------------------------------------------------
# > Fold 1 - Accuracy: 98.89 % - Loss: 0.0454 - Precision: 98.91 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 2 - Accuracy: 98.89 % - Loss: 0.0435 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.89 %
# -------------------------------------------------------------------------------------------------------
# > Fold 3 - Accuracy: 100.00 % - Loss: 0.0231 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 4 - Accuracy: 99.44 % - Loss: 0.0513 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 5 - Accuracy: 100.00 % - Loss: 0.0305 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 6 - Accuracy: 99.44 % - Loss: 0.0351 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 7 - Accuracy: 100.00 % - Loss: 0.0217 - Precision: 100.00 % - Recall: 100.00 % - F1 Score: 100.00 %
# -------------------------------------------------------------------------------------------------------
# > Fold 8 - Accuracy: 98.89 % - Loss: 0.0286 - Precision: 98.96 % - Recall: 98.89 % - F1 Score: 98.90 %
# -------------------------------------------------------------------------------------------------------
# > Fold 9 - Accuracy: 99.44 % - Loss: 0.0438 - Precision: 99.46 % - Recall: 99.44 % - F1 Score: 99.44 %
# -------------------------------------------------------------------------------------------------------
# > Fold 10 - Accuracy: 98.33 % - Loss: 0.0663 - Precision: 98.37 % - Recall: 98.33 % - F1 Score: 98.34 %
# -------------------------------------------------------------------------------------------------------
# Average scores for all folds:
# - Dataset name :  NEU-CLS
# - Level of decomposition :  5
# - SVM parameters:  {'C': 100, 'gamma': 0.001}
# > Accuracy: 99.33 (+- 0.54)
# > Loss: 0.0389
# > Precision: 99.36 (+- 0.53)
# > Recall: 99.33 (+- 0.54)
# > F1 Score: 99.33 (+- 0.54)
# ----------------------------------------------------------------
